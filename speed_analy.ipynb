# %%
import geopandas as gpd
import pyarrow
import pandas as pd
import os

# %%
speed_limit = pd.read_csv('./data/GPS.nosync/Speed_Limits_(County-Maintained_Roads).csv')

# %%
import osmnx as ox
import matplotlib.pyplot as plt


place_name = "Sonoma County, California, USA"

graph = ox.graph_from_place(place_name)
graph
# Out:
# /home/UFAD/xiongruoyang/.local/lib/python3.6/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/UFAD/xiongruoyang/.local/lib/python3.6/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/UFAD/xiongruoyang/.local/lib/python3.6/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
fig, ax = ox.plot_graph(graph)

plt.

# %%
streets = gpd.read_file('data/GPS.nosync/Streets/Streets.shp')

# %%
import json
json_file = open("data/GPS.nosync/openstreetbrowser.geojson")
data = json.load(json_file)

# %%
# !pip install osm-runner
# Out:
# ...
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/2d/61/08076519c80041bc0ffa1a8af0cbd3bf3e2b62af10435d269a9d0f40564d/requests-2.27.1-py2.py3-none-any.whl
# ...
#   Cache entry deserialization failed, entry ignored
#   Using cached https://files.pythonhosted.org/packages/db/83/7d4008ffc2988066ff37f6a0bb6d7b60822367dcb36ba5e39aa7801fda54/pandas-0.24.2-cp27-cp27mu-manylinux1_x86_64.whl
# ...
#     100% |████████████████████████████████| 3.8MB 403kB/s ta 0:00:0101
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-build-BzC36Y/arcgis/setup.py", line 224
#         return f"{MAJOR}.{MINOR}.{MICRO}"
#                                         ^
#     SyntaxError: invalid syntax
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-build-BzC36Y/arcgis/
